# %% [markdown]
# <a href="https://colab.research.google.com/github/DhivyaaSP/Deep-Learning/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import model_to_dot
from IPython.display import SVG

import numpy as np
import matplotlib.pyplot as plt
import time

# Ensure TensorFlow uses the GPU, if available
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Set TensorFlow to only use the first GPU and enable memory growth
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# %%
num_classes = 7   # angry, disgust, fear, happy, neutral, sad, and surprise

# %%
trainingset = np.loadtxt('/content/drive/MyDrive/fer2013_training_onehot.csv', delimiter=',')
testingset = np.loadtxt('/content/drive/MyDrive/fer2013_publictest_onehot.csv', delimiter=',')

trainingset
# Out:
# array([[ 70.,  80.,  82., ...,   0.,   0.,   0.],
#        [151., 150., 147., ...,   0.,   0.,   0.],
#        [231., 212., 156., ...,   0.,   0.,   0.],
#        ...,
#        [ 74.,  81.,  87., ...,   1.,   0.,   0.],
#        [222., 227., 203., ...,   0.,   0.,   0.],
#        [195., 199., 205., ...,   1.,   0.,   0.]])

# %%
n_inputs = 2304
n_classes = 7
img_dim = 48

x_training = trainingset[:, 0:n_inputs]
y_training = trainingset[:, n_inputs:n_inputs + n_classes]

x_testing = testingset[:, 0:n_inputs]
y_testing = testingset[:, n_inputs:n_inputs + n_classes]

x_training = x_training.reshape(x_training.shape[0], 48, 48)
x_training = np.expand_dims(x_training, axis=3)

x_testing = x_testing.reshape(x_testing.shape[0], 48, 48)
x_testing = np.expand_dims(x_testing, axis=3)

# Assuming y_training and y_testing are one-hot encoded
y_training_int = np.argmax(y_training, axis=1)
y_testing_int = np.argmax(y_testing, axis=1)

unique, counts = np.unique(y_training_int, return_counts=True)
print("Training set:")
for label, count in zip(unique, counts):
    print(f"Class {label}: {count} samples")

unique, counts = np.unique(y_testing_int, return_counts=True)
print("\nTesting set:")
for label, count in zip(unique, counts):
    print(f"Class {label}: {count} samples")

train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Fit the data generator to your data
train_datagen.fit(x_training)
# Out:
# Training set:
# Class 0: 3995 samples
# Class 1: 436 samples
# Class 2: 4097 samples
# Class 3: 7215 samples
# Class 4: 4830 samples
# Class 5: 3171 samples
# Class 6: 4965 samples
#
# Testing set:
# Class 0: 467 samples
# Class 1: 56 samples
# Class 2: 496 samples
# Class 3: 895 samples
# Class 4: 653 samples
# Class 5: 415 samples
# Class 6: 607 samples

# %%
# 64x64 portray image
input_image = Input(shape=(48, 48, 1), name='Input')

# First block of conv + maxpool + dropout
x = Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu', name='conv1_1')(input_image)
x = Conv2D(filters=64, kernel_size=(3, 3), padding='valid', activation='relu', name='conv1_2')(x)
x = MaxPooling2D(pool_size=(2, 2), name='pool1')(x)
x = Dropout(rate=0.25, name='conv_dropout1')(x)

# Prepare skip connection with Conv2D for matching dimensions
skip_connection1 = Conv2D(filters=128, kernel_size=(3, 3), padding='valid', name='SkipConnection_1')(x)

# Second block
x = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu', name='conv2_1')(x)
x = Conv2D(filters=128, kernel_size=(3, 3), padding='valid', activation='relu', name='conv2_2')(x)
x = Add()([x, skip_connection1])
x = Conv2D(filters=218, kernel_size=(3, 3), padding='same', activation='relu', name='conv2_3')(x)
x = Conv2D(filters=218, kernel_size=(3, 3), padding='valid', activation='relu', name='conv2_4')(x)
x = MaxPooling2D(pool_size=(2, 2), name='pool2')(x)
x = Dropout(rate=0.25, name='conv_dropout2')(x)

# Third block (4 Conv2D, 1 MaxPooling2D, 1 Dropout)
x = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu', name='conv3_1')(x)
x = Conv2D(filters=256, kernel_size=(3, 3), padding='valid', activation='relu', name='conv3_2')(x)
x = MaxPooling2D(pool_size=(2, 2), name='pool3')(x)
x = Dropout(rate=0.25, name='conv_dropout3')(x)

x = Flatten(name='flatten')(x)

# FC layers + dropout
x = Dense(units=1024, activation='relu', name='fc1')(x)
x = Dropout(rate=0.5, name='fc_dropout1')(x)

x = Dense(units=512, activation='relu', name='fc2')(x)
x = Dropout(rate=0.5, name='fc_dropout2')(x)

output_label = Dense(units=num_classes, activation='softmax', name='fc3_7ways_softmax')(x)

# define model
model = Model(inputs=input_image, outputs=output_label, name='emo_cnn')

# Print model summary to verify the architecture
model.summary()
# Out:
# Model: "emo_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Input (InputLayer)          [(None, 48, 48, 1)]          0         []
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)           640       ['Input[0][0]']
#
#  conv1_2 (Conv2D)            (None, 46, 46, 64)           36928     ['conv1_1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 23, 23, 64)           0         ['conv1_2[0][0]']
#
#  conv_dropout1 (Dropout)     (None, 23, 23, 64)           0         ['pool1[0][0]']
#
#  conv2_1 (Conv2D)            (None, 23, 23, 128)          73856     ['conv_dropout1[0][0]']
#
#  conv2_2 (Conv2D)            (None, 21, 21, 128)          147584    ['conv2_1[0][0]']
#
#  SkipConnection_1 (Conv2D)   (None, 21, 21, 128)          73856     ['conv_dropout1[0][0]']
#
#  add_1 (Add)                 (None, 21, 21, 128)          0         ['conv2_2[0][0]',
#                                                                      'SkipConnection_1[0][0]']
#
#  conv2_3 (Conv2D)            (None, 21, 21, 218)          251354    ['add_1[0][0]']
#
#  conv2_4 (Conv2D)            (None, 19, 19, 218)          427934    ['conv2_3[0][0]']
#
#  pool2 (MaxPooling2D)        (None, 9, 9, 218)            0         ['conv2_4[0][0]']
#
#  conv_dropout2 (Dropout)     (None, 9, 9, 218)            0         ['pool2[0][0]']
#
#  conv3_1 (Conv2D)            (None, 9, 9, 256)            502528    ['conv_dropout2[0][0]']
#
#  conv3_2 (Conv2D)            (None, 7, 7, 256)            590080    ['conv3_1[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 3, 3, 256)            0         ['conv3_2[0][0]']
#
#  conv_dropout3 (Dropout)     (None, 3, 3, 256)            0         ['pool3[0][0]']
#
#  flatten (Flatten)           (None, 2304)                 0         ['conv_dropout3[0][0]']
#
#  fc1 (Dense)                 (None, 1024)                 2360320   ['flatten[0][0]']
#
#  fc_dropout1 (Dropout)       (None, 1024)                 0         ['fc1[0][0]']
#
#  fc2 (Dense)                 (None, 512)                  524800    ['fc_dropout1[0][0]']
#
#  fc_dropout2 (Dropout)       (None, 512)                  0         ['fc2[0][0]']
#
#  fc3_7ways_softmax (Dense)   (None, 7)                    3591      ['fc_dropout2[0][0]']
#
# ==================================================================================================
# Total params: 4993471 (19.05 MB)
# Trainable params: 4993471 (19.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='/content/drive/MyDrive/model.png', show_shapes=True)
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
# declare learning rate, loss function, and model metric
loss = 'categorical_crossentropy'
model.compile(loss=loss, optimizer=Adam(learning_rate=0.0003), metrics=['accuracy'])

# train the model
batch_size = 128
epochs = 75

# Configure batch size and retrieve a batch of images
train_generator = train_datagen.flow(
    x_training,
    y_training,
    batch_size=batch_size
)

starting_time = time.time()
history = model.fit(
    train_generator,
    steps_per_epoch=x_training.shape[0] // batch_size,
    validation_data=(x_testing, y_testing),
    epochs=epochs,
    verbose=1
)
print('> training time is %.4f minutes' % ((time.time() - starting_time)/60))
# Out:
# Epoch 1/75
# 224/224 [==============================] - 29s 113ms/step - loss: 2.0716 - accuracy: 0.2348 - val_loss: 1.8438 - val_accuracy: 0.2494
# Epoch 2/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.8246 - accuracy: 0.2464 - val_loss: 1.8145 - val_accuracy: 0.2494
# Epoch 3/75
# 224/224 [==============================] - 25s 111ms/step - loss: 1.8002 - accuracy: 0.2526 - val_loss: 1.7454 - val_accuracy: 0.2881
# Epoch 4/75
# 224/224 [==============================] - 26s 114ms/step - loss: 1.7398 - accuracy: 0.2839 - val_loss: 1.6428 - val_accuracy: 0.3461
# Epoch 5/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.6631 - accuracy: 0.3291 - val_loss: 1.5084 - val_accuracy: 0.4085
# Epoch 6/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.5593 - accuracy: 0.3896 - val_loss: 1.3757 - val_accuracy: 0.4734
# Epoch 7/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.4781 - accuracy: 0.4271 - val_loss: 1.3034 - val_accuracy: 0.5102
# Epoch 8/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.4082 - accuracy: 0.4601 - val_loss: 1.2903 - val_accuracy: 0.5121
# Epoch 9/75
# 224/224 [==============================] - 25s 111ms/step - loss: 1.3477 - accuracy: 0.4855 - val_loss: 1.2426 - val_accuracy: 0.5202
# Epoch 10/75
# 224/224 [==============================] - 26s 114ms/step - loss: 1.3161 - accuracy: 0.4961 - val_loss: 1.2051 - val_accuracy: 0.5375
# Epoch 11/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.2860 - accuracy: 0.5143 - val_loss: 1.1627 - val_accuracy: 0.5447
# Epoch 12/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.2561 - accuracy: 0.5241 - val_loss: 1.1690 - val_accuracy: 0.5548
# Epoch 13/75
# 224/224 [==============================] - 25s 111ms/step - loss: 1.2336 - accuracy: 0.5335 - val_loss: 1.1227 - val_accuracy: 0.5653
# Epoch 14/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.2099 - accuracy: 0.5439 - val_loss: 1.1314 - val_accuracy: 0.5653
# Epoch 15/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.1928 - accuracy: 0.5496 - val_loss: 1.1263 - val_accuracy: 0.5642
# Epoch 16/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.1813 - accuracy: 0.5550 - val_loss: 1.1121 - val_accuracy: 0.5734
# Epoch 17/75
# 224/224 [==============================] - 26s 114ms/step - loss: 1.1597 - accuracy: 0.5622 - val_loss: 1.1074 - val_accuracy: 0.5818
# Epoch 18/75
# 224/224 [==============================] - 26s 114ms/step - loss: 1.1405 - accuracy: 0.5703 - val_loss: 1.0766 - val_accuracy: 0.5857
# Epoch 19/75
# 224/224 [==============================] - 25s 113ms/step - loss: 1.1262 - accuracy: 0.5786 - val_loss: 1.0731 - val_accuracy: 0.5871
# Epoch 20/75
# 224/224 [==============================] - 25s 111ms/step - loss: 1.1109 - accuracy: 0.5829 - val_loss: 1.0589 - val_accuracy: 0.5968
# Epoch 21/75
# 224/224 [==============================] - 25s 113ms/step - loss: 1.0993 - accuracy: 0.5878 - val_loss: 1.0658 - val_accuracy: 0.6007
# Epoch 22/75
# 224/224 [==============================] - 25s 113ms/step - loss: 1.0930 - accuracy: 0.5923 - val_loss: 1.0691 - val_accuracy: 0.5985
# Epoch 23/75
# 224/224 [==============================] - 25s 111ms/step - loss: 1.0843 - accuracy: 0.5947 - val_loss: 1.0712 - val_accuracy: 0.6002
# Epoch 24/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.0650 - accuracy: 0.6033 - val_loss: 1.0500 - val_accuracy: 0.6055
# Epoch 25/75
# 224/224 [==============================] - 25s 113ms/step - loss: 1.0521 - accuracy: 0.6055 - val_loss: 1.0203 - val_accuracy: 0.6138
# Epoch 26/75
# 224/224 [==============================] - 25s 112ms/step - loss: 1.0535 - accuracy: 0.6068 - val_loss: 1.0310 - val_accuracy: 0.6127
# Epoch 27/75
# 224/224 [==============================] - 25s 113ms/step - loss: 1.0331 - accuracy: 0.6156 - val_loss: 1.0465 - val_accuracy: 0.6124
# Epoch 28/75
# 224/224 [==============================] - 25s 111ms/step - loss: 1.0330 - accuracy: 0.6134 - val_loss: 1.0305 - val_accuracy: 0.6177
# Epoch 29/75
# 224/224 [==============================] - 25s 113ms/step - loss: 1.0190 - accuracy: 0.6185 - val_loss: 1.0270 - val_accuracy: 0.6219
# Epoch 30/75
# 224/224 [==============================] - 25s 110ms/step - loss: 1.0136 - accuracy: 0.6194 - val_loss: 1.0010 - val_accuracy: 0.6280
# Epoch 31/75
# 224/224 [==============================] - 25s 111ms/step - loss: 1.0101 - accuracy: 0.6215 - val_loss: 1.0149 - val_accuracy: 0.6160
# Epoch 32/75
# 224/224 [==============================] - 25s 110ms/step - loss: 0.9959 - accuracy: 0.6293 - val_loss: 1.0028 - val_accuracy: 0.6286
# Epoch 33/75
# 224/224 [==============================] - 26s 114ms/step - loss: 0.9860 - accuracy: 0.6317 - val_loss: 1.0077 - val_accuracy: 0.6283
# Epoch 34/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9924 - accuracy: 0.6333 - val_loss: 0.9928 - val_accuracy: 0.6325
# Epoch 35/75
# 224/224 [==============================] - 25s 109ms/step - loss: 0.9743 - accuracy: 0.6396 - val_loss: 1.0097 - val_accuracy: 0.6300
# Epoch 36/75
# 224/224 [==============================] - 25s 114ms/step - loss: 0.9727 - accuracy: 0.6365 - val_loss: 0.9973 - val_accuracy: 0.6266
# Epoch 37/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9600 - accuracy: 0.6407 - val_loss: 0.9929 - val_accuracy: 0.6319
# Epoch 38/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.9615 - accuracy: 0.6411 - val_loss: 0.9955 - val_accuracy: 0.6339
# Epoch 39/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.9508 - accuracy: 0.6465 - val_loss: 1.0016 - val_accuracy: 0.6395
# Epoch 40/75
# 224/224 [==============================] - 26s 114ms/step - loss: 0.9439 - accuracy: 0.6486 - val_loss: 0.9653 - val_accuracy: 0.6389
# Epoch 41/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9399 - accuracy: 0.6475 - val_loss: 0.9712 - val_accuracy: 0.6414
# Epoch 42/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9407 - accuracy: 0.6490 - val_loss: 0.9839 - val_accuracy: 0.6439
# Epoch 43/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.9321 - accuracy: 0.6538 - val_loss: 0.9667 - val_accuracy: 0.6434
# Epoch 44/75
# 224/224 [==============================] - 25s 113ms/step - loss: 0.9213 - accuracy: 0.6537 - val_loss: 0.9567 - val_accuracy: 0.6495
# Epoch 45/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9169 - accuracy: 0.6565 - val_loss: 0.9668 - val_accuracy: 0.6439
# Epoch 46/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.9168 - accuracy: 0.6579 - val_loss: 0.9672 - val_accuracy: 0.6481
# Epoch 47/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9089 - accuracy: 0.6610 - val_loss: 0.9708 - val_accuracy: 0.6445
# Epoch 48/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9093 - accuracy: 0.6600 - val_loss: 0.9830 - val_accuracy: 0.6383
# Epoch 49/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9052 - accuracy: 0.6618 - val_loss: 0.9870 - val_accuracy: 0.6395
# Epoch 50/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.9007 - accuracy: 0.6643 - val_loss: 0.9607 - val_accuracy: 0.6517
# Epoch 51/75
# 224/224 [==============================] - 25s 110ms/step - loss: 0.8892 - accuracy: 0.6699 - val_loss: 0.9719 - val_accuracy: 0.6528
# Epoch 52/75
# 224/224 [==============================] - 26s 114ms/step - loss: 0.8835 - accuracy: 0.6702 - val_loss: 0.9622 - val_accuracy: 0.6478
# Epoch 53/75
# 224/224 [==============================] - 25s 110ms/step - loss: 0.8869 - accuracy: 0.6678 - val_loss: 0.9698 - val_accuracy: 0.6442
# Epoch 54/75
# 224/224 [==============================] - 25s 110ms/step - loss: 0.8796 - accuracy: 0.6749 - val_loss: 0.9629 - val_accuracy: 0.6484
# Epoch 55/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8683 - accuracy: 0.6775 - val_loss: 0.9674 - val_accuracy: 0.6489
# Epoch 56/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.8704 - accuracy: 0.6762 - val_loss: 0.9904 - val_accuracy: 0.6453
# Epoch 57/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8654 - accuracy: 0.6785 - val_loss: 0.9725 - val_accuracy: 0.6492
# Epoch 58/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8562 - accuracy: 0.6842 - val_loss: 0.9634 - val_accuracy: 0.6604
# Epoch 59/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8585 - accuracy: 0.6810 - val_loss: 0.9729 - val_accuracy: 0.6495
# Epoch 60/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.8527 - accuracy: 0.6791 - val_loss: 0.9966 - val_accuracy: 0.6445
# Epoch 61/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.8455 - accuracy: 0.6869 - val_loss: 0.9511 - val_accuracy: 0.6565
# Epoch 62/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8369 - accuracy: 0.6890 - val_loss: 0.9951 - val_accuracy: 0.6601
# Epoch 63/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.8390 - accuracy: 0.6912 - val_loss: 0.9558 - val_accuracy: 0.6584
# Epoch 64/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8307 - accuracy: 0.6909 - val_loss: 0.9878 - val_accuracy: 0.6459
# Epoch 65/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8255 - accuracy: 0.6963 - val_loss: 0.9510 - val_accuracy: 0.6595
# Epoch 66/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8262 - accuracy: 0.6954 - val_loss: 0.9628 - val_accuracy: 0.6556
# Epoch 67/75
# 224/224 [==============================] - 25s 113ms/step - loss: 0.8173 - accuracy: 0.6947 - val_loss: 0.9556 - val_accuracy: 0.6581
# Epoch 68/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.8206 - accuracy: 0.6957 - val_loss: 0.9733 - val_accuracy: 0.6498
# Epoch 69/75
# 224/224 [==============================] - 25s 113ms/step - loss: 0.8124 - accuracy: 0.6988 - val_loss: 0.9644 - val_accuracy: 0.6551
# Epoch 70/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.8128 - accuracy: 0.6975 - val_loss: 0.9669 - val_accuracy: 0.6512
# Epoch 71/75
# 224/224 [==============================] - 25s 113ms/step - loss: 0.8047 - accuracy: 0.7013 - val_loss: 0.9763 - val_accuracy: 0.6595
# Epoch 72/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8102 - accuracy: 0.7005 - val_loss: 0.9985 - val_accuracy: 0.6542
# Epoch 73/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.7975 - accuracy: 0.7016 - val_loss: 1.0122 - val_accuracy: 0.6453
# Epoch 74/75
# 224/224 [==============================] - 25s 112ms/step - loss: 0.8015 - accuracy: 0.7011 - val_loss: 0.9557 - val_accuracy: 0.6620
# Epoch 75/75
# 224/224 [==============================] - 25s 111ms/step - loss: 0.8004 - accuracy: 0.7045 - val_loss: 0.9495 - val_accuracy: 0.6576
# > training time is 39.8924 minutes

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "training_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "training_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.legend()

plot_curves(history)

# %%
score = model.evaluate(x_testing, y_testing)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 113/113 [==============================] - 1s 9ms/step - loss: 0.9495 - accuracy: 0.6576
# Test loss: 0.9495108723640442
# Test accuracy: 0.6575647592544556

# %%
def get_emotion(ohv):
    indx = np.argmax(ohv)

    if indx == 0:
        return 'angry'
    elif indx == 1:
        return 'disgust'
    elif indx == 2:
        return 'fear'
    elif indx == 3:
        return 'happy'
    elif indx == 4:
        return 'sad'
    elif indx == 5:
        return 'surprise'
    elif indx == 6:
        return 'neutral'

# %%
# 2163
img_indx = np.uint32(np.random.rand()*(testingset.shape[0] - 1))
sample = x_testing[img_indx, :]
sample = sample.reshape(48, 48)

pred_cls = model.predict(sample.reshape(1, 48, 48, 1))

plt.imshow(sample, cmap='gray')
plt.show()
print('> testing image index: %d\n> true emotion: %s\n> predicted emotion: %s' % (img_indx, get_emotion(y_testing[img_indx, :]), get_emotion(pred_cls)))
# Out:
# 1/1 [==============================] - 0s 127ms/step
# > testing image index: 1314
# > true emotion: sad
# > predicted emotion: sad

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Make predictions for the entire test set
predictions = model.predict(x_testing)

# Convert predictions and true labels from one-hot vectors to integers
y_pred = np.argmax(predictions, axis=1)
y_true = np.argmax(y_testing, axis=1)
cm = confusion_matrix(y_true, y_pred)
# Define class names as a list
class_names = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# 113/113 [==============================] - 1s 7ms/step
